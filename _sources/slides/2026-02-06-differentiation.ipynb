# %% [markdown]
# # 2026-02-06 Differentiation

# %% [markdown]
# ## Last time
#
# * Newton's method for systems
# * Bratu nonlinear PDE
#
# ## Today
#
# * p-Laplacian
# * NLsolve Newton solver library
#   * p-Laplacian robustness
#   * diagnostics
# * Algorithmic differentiation via Zygote
# * Symbolic differentiation
# * Structured by-hand differentiation
# * Concept of PDE-based inference (inverse problems)

# %%
using Plots
default(linewidth=3)
using LinearAlgebra
using SparseArrays

function vander(x, k=nothing)
    if k === nothing
        k = length(x)
    end
    V = ones(length(x), k)
    for j = 2:k
        V[:, j] = V[:, j-1] .* x
    end
    V
end

function fdstencil(source, target, k)
    "kth derivative stencil from source to target"
    x = source .- target
    V = vander(x)
    rhs = zero(x)'
    rhs[k+1] = factorial(k)
    rhs / V
end

function my_spy(A)
    cmax = norm(vec(A), Inf)
    s = max(1, ceil(120 / size(A, 1)))
    spy(A, marker=(:square, s), c=:diverging_rainbow_bgymr_45_85_c67_n256, clims=(-cmax, cmax))
end


function advdiff_sparse(n, kappa, wind, forcing)
    x = LinRange(-1, 1, n)
    xstag = (x[1:end-1] + x[2:end]) / 2
    rhs = forcing.(x)
    kappa_stag = kappa.(xstag)
    rows = [1, n]
    cols = [1, n]
    vals = [1., 1.] # diagonals entries (float)
    rhs[[1,n]] .= 0 # boundary condition
    for i in 2:n-1
        flux_L = -kappa_stag[i-1] * fdstencil(x[i-1:i], xstag[i-1], 1) +
            wind * (wind > 0 ? [1 0] : [0 1])
        flux_R = -kappa_stag[i] * fdstencil(x[i:i+1], xstag[i], 1) +
            wind * (wind > 0 ? [1 0] : [0 1])
        weights = fdstencil(xstag[i-1:i], x[i], 1)
        append!(rows, [i,i,i])
        append!(cols, i-1:i+1)
        append!(vals, weights[1] *  [flux_L..., 0] + weights[2] * [0, flux_R...])
    end
    L = sparse(rows, cols, vals)
    x, L, rhs
end

function newton(residual, jacobian, u0; maxits=20)
    u = u0
    uhist = [copy(u)]
    normhist = []
    for k in 1:maxits
        f = residual(u)
        push!(normhist, norm(f))
        J = jacobian(u)
        delta_u = - J \ f
        u += delta_u
        push!(uhist, copy(u))
    end
    uhist, normhist
end
# Out:
# newton (generic function with 1 method)

# %% [markdown]
# # $p$-Laplacian
#
# $$ -\big(|u_x|^{p-2} u_x\big)_x = b(x) \text{ in } \Omega = (-1, 1), \quad u(-1) = 0, u(1) = 1 $$

# %%
plaplace_p = 1.5
plaplace_forcing = 0. # b(x) above
function plaplace_f(u)
    n = length(u)
    h = 2 / (n - 1)
    u = copy(u)
    f = copy(u)
    u[[1, n]] = [0, 1]
    f[n] -= 1
    for i in 2:n-1
        u_xstag = diff(u[i-1:i+1]) / h
        kappa_stag = abs.(u_xstag) .^ (plaplace_p - 2)
        f[i] = [1/h, -1/h]' *
            (kappa_stag .* u_xstag) - plaplace_forcing
    end
    f
end
# Out:
# plaplace_f (generic function with 1 method)

# %%
function plaplace_J(u)
    n = length(u)
    h = 2 / (n - 1)
    u = copy(u)
    u[[1, n]] = [0, 1]
    rows = [1, n]
    cols = [1, n]
    vals = [1., 1.] # diagonals entries (float)
    for i in 2:n-1
        js = i-1:i+1
        u_xstag = diff(u[js]) / h
        kappa_stag = abs.(u_xstag) .^ (plaplace_p - 2)
        fi = [h, -h]' * (kappa_stag .* u_xstag)
        fi_ujs = [-kappa_stag[1]/h^2,
                  sum(kappa_stag)/h^2,
                  -kappa_stag[2]/h^2]
        mask = 1 .< js .< n
        append!(rows, [i,i,i][mask])
        append!(cols, js[mask])
        append!(vals, fi_ujs[mask])
    end
    sparse(rows, cols, vals)
end
# Out:
# plaplace_J (generic function with 1 method)

# %% [markdown]
# # Try solving

# %%
n = 20
x = collect(LinRange(-1., 1, n))
u0 = (1 .+ x) / 2

plaplace_p = 1.5 # try different values
plaplace_forcing = 1
uhist, normhist = newton(plaplace_f, plaplace_J, u0; maxits=20);
plot(normhist, marker=:circle, yscale=:log10, ylims=(1e-10, 1e3))

# %%
plot(x, uhist[1:5:end], marker=:auto, legend=:bottomright)

# %% [markdown]
# ## What's wrong?

# %% [markdown]
# # Using Zygote to differentiate

# %%
using Zygote

gradient(x -> x^2, 3)
# Out:
# (6.0,)

# %%
function plaplace_fpoint(u, h)
    u_xstag = diff(u) / h
    kappa_stag = abs.(u_xstag) .^ (plaplace_p - 2)
    [1/h, -1/h]' * (kappa_stag .* u_xstag)
end

gradient(u -> plaplace_fpoint(u, .1), [0., .7, 1.])
# Out:
# ([-18.898223650461365, 47.76573710994265, -28.867513459481284],)

# %% [markdown]
# # p-Laplacian with Zygote

# %%
function plaplace_fzygote(u)
    n = length(u)
    h = 2 / (n - 1)
    u = copy(u)
    f = copy(u)
    u[[1, n]] = [0, 1]
    f[n] -= 1
    for i in 2:n-1
        f[i] = plaplace_fpoint(u[i-1:i+1], h) - plaplace_forcing
    end
    f
end
# Out:
# plaplace_fzygote (generic function with 1 method)

# %%
function plaplace_Jzygote(u)
    n = length(u)
    h = 2 / (n - 1)
    u = copy(u)
    u[[1, n]] = [0, 1]
    rows = [1, n]
    cols = [1, n]
    vals = [1., 1.] # diagonals entries (float)
    for i in 2:n-1
        js = i-1:i+1
        fi_ujs = gradient(ujs -> plaplace_fpoint(ujs, h), u[js])[1]
        mask = 1 .< js .< n
        append!(rows, [i,i,i][mask])
        append!(cols, js[mask])
        append!(vals, fi_ujs[mask])
    end
    sparse(rows, cols, vals)
end
# Out:
# plaplace_Jzygote (generic function with 1 method)

# %% [markdown]
# # Experiment with parameters

# %%
plaplace_p = 1.5
plaplace_forcing = 1
u0 = (x .+ 1) / 2
uhist, normhist = newton(plaplace_fzygote, plaplace_Jzygote, u0; maxits=50);
plot(normhist, marker=:auto, yscale=:log10)

# %%
plot(x, uhist[1:5:end], marker=:auto, legend=:topleft)

# %% [markdown]
# * Can you fix the `plaplace_J` to differentiate correctly (analytically)?
# * What is causing Newton to diverge?
# * How might we fix or work around it?

# %% [markdown]
# # A model problem for Newton divergence; compare NLsolve

# %%
k = 1.1 # what happens as this is changed
fk(x) = tanh.(k*(x.+0.5))
Jk(x) = reshape(k / cosh.(k*(x.+0.5)).^2, 1, 1)
xhist, normhist = newton(fk, Jk, [1.], maxits=10)
plot(xhist, fk.(xhist), marker=:circle, legend=:bottomright)
plot!(fk, xlims=(-3, 3), linewidth=2)

# %%
# using Pkg; Pkg.add("NLsolve")
using NLsolve

nlsolve(x -> fk(x), Jk, [2.], show_trace=true)
# Out:
# Iter     f(x) inf-norm    Step 2-norm
# ------   --------------   --------------
#      0     9.918597e-01              NaN
#      1     5.005202e-01     2.000000e+00
#      2     1.172815e-01     6.071125e-01
#      3     1.093485e-03     1.081066e-01
#      4     8.716604e-10     9.940781e-04
# Results of Nonlinear Solver Algorithm
#  * Algorithm: Trust-region with dogleg and autoscaling
#  * Starting Point: [2.0]
#  * Zero: [-0.5000000007924186]
#  * Inf-norm of residuals: 0.000000
#  * Iterations: 4
#  * Convergence: true
#    * |x - x'| < 0.0e+00: false
#    * |f(x)| < 1.0e-08: true
#  * Function Calls (f): 5
#  * Jacobian Calls (df/dx): 5

# %% [markdown]
# # [NLsolve](https://juliapackages.com/p/nlsolve) for p-Laplacian

# %%
plaplace_p = 1.45
plaplace_forcing = 1
u0 = (x .+ 1) / 2
sol = nlsolve(plaplace_fzygote, plaplace_Jzygote, u0, 
    store_trace=true)
plaplace_p = 1.3
sol = nlsolve(plaplace_fzygote, plaplace_Jzygote, sol.zero, 
    store_trace=true)
fnorms = [sol.trace[i].fnorm for i in 1:sol.iterations]
plot(fnorms, marker=:circle, yscale=:log10)

# %%
plot(x, [sol.initial_x sol.zero], label=["initial" "solution"])

# %% [markdown]
# # What about symbolic differentiation?

# %%
import Symbolics: Differential, expand_derivatives, @variables
@variables x
Dx = Differential(x)
y = tanh(k*x)
Dx(y)
# Out:
# Differential(x, 1)(tanh(1.1x))

# %%
expand_derivatives(Dx(y))
# Out:
# 30.1(1 - (tanh(30.1x)^2))

# %% [markdown]
# # Cool, what about composition of functions

# %%
y = x
for _ in 1:2
    y = cos(y^pi) * log(y)
end
expand_derivatives(Dx(y))
# Out:
# ((cos(x^π) / x - 3.141592653589793(x^2.141592653589793)*sin(x^π)*log(x))*cos((cos(x^π)^3.141592653589793)*(log(x)^3.141592653589793))) / (cos(x^π)*log(x)) - ((3.141592653589793(cos(x^π)^3.141592653589793)*(log(x)^2.141592653589793)) / x - 9.869604401089358(x^2.141592653589793)*(cos(x^π)^2.141592653589793)*sin(x^π)*(log(x)^3.141592653589793))*sin((cos(x^π)^3.141592653589793)*(log(x)^3.141592653589793))*log(cos(x^π)*log(x))

# %% [markdown]
# * The size of these expressions can grow **exponentially**.

# %% [markdown]
# # Hand coding derivatives: it's all chain rule and associativity
# $$ df = f'(x) dx $$

# %%
function f(x)
    y = x
    for _ in 1:2
        a = y^pi
        b = cos(a)
        c = log(y)
        y = b * c
    end
    y
end

f(1.9), gradient(f, 1.9)
# Out:
# (-1.5346823414986814, (-34.03241959914049,))

# %%
function df(x, dx)
    y = x
    dy = dx
    for _ in 1:2
        a = y^pi
        da = pi * y^(pi-1) * dy
        b = cos(a)
        db = -sin(a) * da
        c = log(y)
        dc = 1/y * dy
        y = b * c
        dy = db * c + b * dc
    end
    dy
end

df(1.9, 1)
# Out:
# -34.03241959914048

# %% [markdown]
# # We can go the other way
#
# We can differentiate a composition $h(g(f(x)))$ as
#
# \begin{align}
#   \operatorname{d} h &= h' \operatorname{d} g \\
#   \operatorname{d} g &= g' \operatorname{d} f \\
#   \operatorname{d} f &= f' \operatorname{d} x.
# \end{align}
#
# What we've done above is called "forward mode", and amounts to placing the parentheses in the chain rule like
#
# $$ \operatorname d h = \frac{dh}{dg} \left(\frac{dg}{df} \left(\frac{df}{dx} \operatorname d x \right) \right) .$$
#
# The expression means the same thing if we rearrange the parentheses,
#
# $$ \operatorname d h = \left( \left( \left( \frac{dh}{dg} \right) \frac{dg}{df} \right) \frac{df}{dx} \right) \operatorname d x $$
#
# which we can compute with in reverse order via
#
# $$ \underbrace{\bar x}_{\frac{dh}{dx}} = \underbrace{\bar g \frac{dg}{df}}_{\bar f} \frac{df}{dx} .$$

# %% [markdown]
# # A reverse mode example
#
# $$ \underbrace{\bar x}_{\frac{dh}{dx}} = \underbrace{\bar g \frac{dg}{df}}_{\bar f} \frac{df}{dx} .$$

# %%
function g(x)
    a = x^pi
    b = cos(a)
    c = log(x)
    y = b * c
    y
end
(g(1.4), gradient(g, 1.4))
# Out:
# (-0.32484122107701546, (-1.2559761698835525,))

# %%
function gback(x, y_)
    a = x^pi
    b = cos(a)
    c = log(x)
    y = b * c
    # backward pass
    c_ = y_ * b 
    b_ = c * y_
    a_ = -sin(a) * b_
    x_ = 1/x * c_ + pi * x^(pi-1) * a_
    x_
end
gback(1.4, 1)
# Out:
# -1.2559761698835525

# %% [markdown]
# # Kinds of algorithmic differentation
#
# * Source transformation: Fortran code in, Fortran code out
#   * Duplicates compiler features, usually incomplete language coverage
#   * Produces efficient code
# * Operator overloading: C++ types
#   * Hard to vectorize
#   * Loops are effectively unrolled/inefficient
# * Just-in-time compilation: tightly coupled with compiler
#   * JIT lag
#   * Needs dynamic language features (JAX) or tight integration with compiler (Zygote, Enzyme)
#   * Some [sharp bits](https://jax.readthedocs.io/en/latest/notebooks/Common_Gotchas_in_JAX.html#control-flow)

# %% [markdown]
# # How does Zygote work?

# %%
h1(x) = x^3 + 3*x
h2(x) = ((x * x)  + 3) * x
@code_llvm h2(4.)
# Out:
# ; Function Signature: h2(Float64)
# ;  @ In[94]:2 within `h2`
# define double @julia_h2_40011(double %"x::Float64") #0 {
# top:
# ; ┌ @ float.jl:497 within `*`
#    %0 = fmul double %"x::Float64", %"x::Float64"
# ; └
# ; ┌ @ promotion.jl:433 within `+` @ float.jl:495
#    %1 = fadd double %0, 3.000000e+00
# ; └
# ; ┌ @ float.jl:497 within `*`
#    %2 = fmul double %1, %"x::Float64"
#    ret double %2
# ; └
# }

# %%
@code_llvm gradient(h2, 4.)
# Out:
# ; Function Signature: gradient(typeof(Main.h2), Float64)
# ;  @ /home/jed/.julia/packages/Zygote/55SqB/src/compiler/interface.jl:152 within `gradient`
# define [1 x double] @julia_gradient_40005(double %"args[1]::Float64") #0 {
# top:
# ;  @ /home/jed/.julia/packages/Zygote/55SqB/src/compiler/interface.jl:153 within `gradient`
# ; ┌ @ /home/jed/.julia/packages/Zygote/55SqB/src/compiler/interface.jl:94 within `pullback` @ /home/jed/.julia/packages/Zygote/55SqB/src/compiler/interface.jl:96
# ; │┌ @ In[88]:2 within `h2`
# ; ││┌ @ /home/jed/.julia/packages/Zygote/55SqB/src/compiler/interface2.jl:81 within `_pullback`
# ; │││┌ @ /home/jed/.julia/packages/Zygote/55SqB/src/compiler/interface2.jl within `macro expansion`
# ; ││││┌ @ /home/jed/.julia/packages/Zygote/55SqB/src/compiler/chainrules.jl:234 within `chain_rrule`
# ; │││││┌ @ /home/jed/.julia/packages/ChainRulesCore/Vsbj9/src/rules.jl:138 within `rrule` @ /home/jed/.julia/packages/ChainRules/14CDN/src/rulesets/Base/fastmath_able.jl:259
# ; ││││││┌ @ float.jl:497 within `*`
#          %0 = fmul double %"args[1]::Float64", %"args[1]::Float64"
# ; ││││││└
# ; ││││││ @ /home/jed/.julia/packages/Zygote/55SqB/src/lib/number.jl:32 within `rrule`
# ; ││││││┌ @ promotion.jl:433 within `+` @ float.jl:495
#          %1 = fadd double %0, 3.000000e+00
# ; └└└└└└└
# ;  @ /home/jed/.julia/packages/Zygote/55SqB/src/compiler/interface.jl:154 within `gradient`
# ; ┌ @ /home/jed/.julia/packages/Zygote/55SqB/src/compiler/interface.jl:97 within `#pullback##0`
# ; │┌ @ In[88]:2 within `h2`
# ; ││┌ @ /home/jed/.julia/packages/Zygote/55SqB/src/compiler/chainrules.jl:222 within `ZBack`
# ; │││┌ @ /home/jed/.julia/packages/ChainRules/14CDN/src/rulesets/Base/fastmath_able.jl:257 within `times_pullback2`
# ; ││││┌ @ float.jl:497 within `*`
#        %2 = fadd double %0, %1
#        %3 = fadd double %0, %2
# ; └└└└└
# ;  @ /home/jed/.julia/packages/Zygote/55SqB/src/compiler/interface.jl:155 within `gradient`
#   %"new::Tuple5.unbox.fca.0.insert" = insertvalue [1 x double] zeroinitializer, double %3, 0
#   ret [1 x double] %"new::Tuple5.unbox.fca.0.insert"
# }

# %% [markdown]
# # Forward or reverse?
#
# It all depends on the shape.
#
# $$ \operatorname d h = \frac{dh}{dg} \left(\frac{dg}{df} \left(\frac{df}{dx} \operatorname d x \right) \right) .$$
#
# $$ \operatorname d h = \left( \left( \left( \frac{dh}{dg} \right) \frac{dg}{df} \right) \frac{df}{dx} \right) \operatorname d x $$
#
# * One input, many outputs: use forward mode
#   * "One input" can be looking in one direction
# * Many inputs, one output: use reverse mode
#   * Will need to traverse execution backwards ("tape")
#   * Hierarchical checkpointing
# * About square? Forward is usually a bit more efficient.

# %% [markdown]
# # Inference using PDE-based models
#
# <img src="https://crikit.science/_images/diagram.png" width="100%" />

# %% [markdown]
# # [Compressible Blasius boundary layer](https://en.wikipedia.org/wiki/Blasius_boundary_layer#Compressible_Blasius_boundary_layer)
#
# * Activity will solve this 1D nonlinear PDE
